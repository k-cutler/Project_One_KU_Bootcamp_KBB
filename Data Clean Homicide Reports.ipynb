# %%
#Dependcies
import pandas as pd

# %%
# Make a reference to the file path
csv_path = "Resources/homicide_reports_2000_2014.csv"

# %%
# Read the CSV into a Pandas DataFrame
datasource_df = pd.read_csv(csv_path)

# Print the first five rows of data to the screen
datasource_df.head(10)
# Out:
#    Record ID Agency Code Agency Name       Agency Type       City   State  \
# 0     402433     AK00101   Anchorage  Municipal Police  Anchorage  Alaska
# 1     402434     AK00101   Anchorage  Municipal Police  Anchorage  Alaska
# 2     402435     AK00101   Anchorage  Municipal Police  Anchorage  Alaska
# 3     402436     AK00101   Anchorage  Municipal Police  Anchorage  Alaska
# 4     402437     AK00101   Anchorage  Municipal Police  Anchorage  Alaska
# 5     402438     AK00101   Anchorage  Municipal Police  Anchorage  Alaska
# 6     402439     AK00101   Anchorage  Municipal Police  Anchorage  Alaska
# 7     402440     AK00101   Anchorage  Municipal Police  Anchorage  Alaska
# 8     402441     AK00101   Anchorage  Municipal Police  Anchorage  Alaska
# 9     402442     AK00101   Anchorage  Municipal Police  Anchorage  Alaska
#
#    Year     Month  Incident                  Crime Type  ... Victim Ethnicity  \
# ...

# %%
# Delete extraneous column
del datasource_df["Agency Code"]
datasource_df.head()
# Out:
#    Record ID Agency Name       Agency Type       City   State  Year     Month  \
# 0     402433   Anchorage  Municipal Police  Anchorage  Alaska  2000   January
# 1     402434   Anchorage  Municipal Police  Anchorage  Alaska  2000   January
# 2     402435   Anchorage  Municipal Police  Anchorage  Alaska  2000   January
# 3     402436   Anchorage  Municipal Police  Anchorage  Alaska  2000  February
# 4     402437   Anchorage  Municipal Police  Anchorage  Alaska  2000     March
#
#    Incident                  Crime Type Crime Solved  ... Victim Ethnicity  \
# 0         1      Murder or Manslaughter          Yes  ...          Unknown
# 1         2      Murder or Manslaughter          Yes  ...          Unknown
# 2         3  Manslaughter by Negligence          Yes  ...          Unknown
# 3         1  Manslaughter by Negligence          Yes  ...          Unknown
# 4         1      Murder or Manslaughter           No  ...          Unknown
#
# ...

# %%
# Delete extraneous column
del datasource_df["Agency Name"]
datasource_df.head()
# Out:
#    Record ID       Agency Type       City   State  Year     Month  Incident  \
# 0     402433  Municipal Police  Anchorage  Alaska  2000   January         1
# 1     402434  Municipal Police  Anchorage  Alaska  2000   January         2
# 2     402435  Municipal Police  Anchorage  Alaska  2000   January         3
# 3     402436  Municipal Police  Anchorage  Alaska  2000  February         1
# 4     402437  Municipal Police  Anchorage  Alaska  2000     March         1
#
#                    Crime Type Crime Solved Victim Sex  ...  Victim Ethnicity  \
# 0      Murder or Manslaughter          Yes     Female  ...           Unknown
# 1      Murder or Manslaughter          Yes     Female  ...           Unknown
# 2  Manslaughter by Negligence          Yes       Male  ...           Unknown
# 3  Manslaughter by Negligence          Yes       Male  ...           Unknown
# 4      Murder or Manslaughter           No     Female  ...           Unknown
#
# ...

# %%
# Delete extraneous column
del datasource_df["Agency Type"]
datasource_df.head()
# Out:
#    Record ID       City   State  Year     Month  Incident  \
# 0     402433  Anchorage  Alaska  2000   January         1
# 1     402434  Anchorage  Alaska  2000   January         2
# 2     402435  Anchorage  Alaska  2000   January         3
# 3     402436  Anchorage  Alaska  2000  February         1
# 4     402437  Anchorage  Alaska  2000     March         1
#
#                    Crime Type Crime Solved Victim Sex  Victim Age  ...  \
# 0      Murder or Manslaughter          Yes     Female          25  ...
# 1      Murder or Manslaughter          Yes     Female          31  ...
# 2  Manslaughter by Negligence          Yes       Male           1  ...
# 3  Manslaughter by Negligence          Yes       Male           0  ...
# 4      Murder or Manslaughter           No     Female          29  ...
#
#   Victim Ethnicity Perpetrator Sex Perpetrator Age  \
# 0          Unknown            Male              28
# 1          Unknown            Male              18
# ...

# %%
# Delete extraneous column
del datasource_df["Victim Ethnicity"]
datasource_df.head()
# Out:
#    Record ID       City   State  Year     Month  Incident  \
# 0     402433  Anchorage  Alaska  2000   January         1
# 1     402434  Anchorage  Alaska  2000   January         2
# 2     402435  Anchorage  Alaska  2000   January         3
# 3     402436  Anchorage  Alaska  2000  February         1
# 4     402437  Anchorage  Alaska  2000     March         1
#
#                    Crime Type Crime Solved Victim Sex  Victim Age  \
# 0      Murder or Manslaughter          Yes     Female          25
# 1      Murder or Manslaughter          Yes     Female          31
# 2  Manslaughter by Negligence          Yes       Male           1
# 3  Manslaughter by Negligence          Yes       Male           0
# 4      Murder or Manslaughter           No     Female          29
#
#                      Victim Race Perpetrator Sex Perpetrator Age  \
# 0                          Black            Male              28
# 1                          White            Male              18
# ...

# %%
# Delete extraneous column
del datasource_df["Perpetrator Ethnicity"]
datasource_df.head()
# Out:
#    Record ID       City   State  Year     Month  Incident  \
# 0     402433  Anchorage  Alaska  2000   January         1
# 1     402434  Anchorage  Alaska  2000   January         2
# 2     402435  Anchorage  Alaska  2000   January         3
# 3     402436  Anchorage  Alaska  2000  February         1
# 4     402437  Anchorage  Alaska  2000     March         1
#
#                    Crime Type Crime Solved Victim Sex  Victim Age  \
# 0      Murder or Manslaughter          Yes     Female          25
# 1      Murder or Manslaughter          Yes     Female          31
# 2  Manslaughter by Negligence          Yes       Male           1
# 3  Manslaughter by Negligence          Yes       Male           0
# 4      Murder or Manslaughter           No     Female          29
#
#                      Victim Race Perpetrator Sex Perpetrator Age  \
# 0                          Black            Male              28
# 1                          White            Male              18
# ...

# %%
# Delete extraneous column
del datasource_df["Victim Count"]
datasource_df.head()
# Out:
#    Record ID       City   State  Year     Month  Incident  \
# 0     402433  Anchorage  Alaska  2000   January         1
# 1     402434  Anchorage  Alaska  2000   January         2
# 2     402435  Anchorage  Alaska  2000   January         3
# 3     402436  Anchorage  Alaska  2000  February         1
# 4     402437  Anchorage  Alaska  2000     March         1
#
#                    Crime Type Crime Solved Victim Sex  Victim Age  \
# 0      Murder or Manslaughter          Yes     Female          25
# 1      Murder or Manslaughter          Yes     Female          31
# 2  Manslaughter by Negligence          Yes       Male           1
# 3  Manslaughter by Negligence          Yes       Male           0
# 4      Murder or Manslaughter           No     Female          29
#
#                      Victim Race Perpetrator Sex Perpetrator Age  \
# 0                          Black            Male              28
# 1                          White            Male              18
# ...

# %%
# Delete extraneous column
del datasource_df["Perpetrator Count"]
datasource_df.head()
# Out:
#    Record ID       City   State  Year     Month  Incident  \
# 0     402433  Anchorage  Alaska  2000   January         1
# 1     402434  Anchorage  Alaska  2000   January         2
# 2     402435  Anchorage  Alaska  2000   January         3
# 3     402436  Anchorage  Alaska  2000  February         1
# 4     402437  Anchorage  Alaska  2000     March         1
#
#                    Crime Type Crime Solved Victim Sex  Victim Age  \
# 0      Murder or Manslaughter          Yes     Female          25
# 1      Murder or Manslaughter          Yes     Female          31
# 2  Manslaughter by Negligence          Yes       Male           1
# 3  Manslaughter by Negligence          Yes       Male           0
# 4      Murder or Manslaughter           No     Female          29
#
#                      Victim Race Perpetrator Sex Perpetrator Age  \
# 0                          Black            Male              28
# 1                          White            Male              18
# ...

# %%
# Delete extraneous column
del datasource_df["Record Source"]
datasource_df.head()
# Out:
#    Record ID       City   State  Year     Month  Incident  \
# 0     402433  Anchorage  Alaska  2000   January         1
# 1     402434  Anchorage  Alaska  2000   January         2
# 2     402435  Anchorage  Alaska  2000   January         3
# 3     402436  Anchorage  Alaska  2000  February         1
# 4     402437  Anchorage  Alaska  2000     March         1
#
#                    Crime Type Crime Solved Victim Sex  Victim Age  \
# 0      Murder or Manslaughter          Yes     Female          25
# 1      Murder or Manslaughter          Yes     Female          31
# 2  Manslaughter by Negligence          Yes       Male           1
# 3  Manslaughter by Negligence          Yes       Male           0
# 4      Murder or Manslaughter           No     Female          29
#
#                      Victim Race Perpetrator Sex Perpetrator Age  \
# 0                          Black            Male              28
# 1                          White            Male              18
# ...

# %%
# Delete extraneous column
del datasource_df["Record ID"]
datasource_df.head()
# Out:
#         City   State  Year     Month  Incident                  Crime Type  \
# 0  Anchorage  Alaska  2000   January         1      Murder or Manslaughter
# 1  Anchorage  Alaska  2000   January         2      Murder or Manslaughter
# 2  Anchorage  Alaska  2000   January         3  Manslaughter by Negligence
# 3  Anchorage  Alaska  2000  February         1  Manslaughter by Negligence
# 4  Anchorage  Alaska  2000     March         1      Murder or Manslaughter
#
#   Crime Solved Victim Sex  Victim Age                    Victim Race  \
# 0          Yes     Female          25                          Black
# 1          Yes     Female          31                          White
# 2          Yes       Male           1         Asian/Pacific Islander
# 3          Yes       Male           0         Asian/Pacific Islander
# 4           No     Female          29  Native American/Alaska Native
#
#   Perpetrator Sex Perpetrator Age               Perpetrator Race  \
# ...

# %%
# Push the remade DataFrame to a new CSV file
datasource_df.to_csv("Output/clean_data.csv",
                  encoding="utf-8", index=False, header=True)
