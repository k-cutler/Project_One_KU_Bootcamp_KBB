# %%
#Dependcies
import pandas as pd

# %%
# Make a reference to the file path
csv_path = "Resources/data_2015-2016.csv"

# %%
# Read the CSV into a Pandas DataFrame
data_source1_df = pd.read_csv(csv_path)

# Print the first five rows of data to the screen
data_source1_df.head(400)
# Out:
#    Control of institution     State  \
# 0                  Public    Kansas
# 1                  Public    Kansas
# 2                  Public    Kansas
# 3                  Public    Kansas
# 4                  Public    Kansas
# 5                  Public    Kansas
# 6                  Public    Kansas
# 7                  Public    Kansas
# 8                  Public    Kansas
# 9                  Public    Kansas
# 10                 Public    Kansas
# 11                 Public    Kansas
# 12                 Public    Kansas
# 13                 Public    Kansas
# 14                 Public    Kansas
# 15                 Public    Kansas
# 16                 Public    Kansas
# 17                 Public    Kansas
# 18                 Public    Kansas
# 19                 Public    Kansas
# 20                 Public    Kansas
# 21                 Public    Kansas
# 22                 Public    Kansas
# 23                 Public    Kansas
# 24                 Public    Kansas
# ...

# %%
# Delete extraneous column
del data_source1_df['MEDIAN']
data_source1_df.head()
# Out:
#   Control of institution   State  \
# 0                 Public  Kansas
# 1                 Public  Kansas
# 2                 Public  Kansas
# 3                 Public  Kansas
# 4                 Public  Kansas
#
#                                             Variable     SUM     MIN     MAX  \
# 0  Total number of full-time first-time degree/ce...   4,032   4,032   4,032
# 1  Total number of undergraduates - financial aid...  19,245  19,245  19,245
# 2  Grand total - 4-year institutions, Completers ...   2,213   2,213   2,213
# 3  Grand total - Bachelor's or equiv subcohort (4...   2,213   2,213   2,213
# 4  In-district average tuition for full-time unde...   9,579   9,579   9,579
#
#       AVG  25PERCENT  75PERCENT  STDEV
# 0   4,032     4032.0        NaN    NaN
# 1  19,245    19245.0        NaN    NaN
# 2   2,213     2213.0        NaN    NaN
# 3   2,213     2213.0        NaN    NaN
# 4   9,579     9579.0        NaN    NaN

# %%
# Delete extraneous column
del data_source1_df['75PERCENT']
data_source1_df.head()
# Out:
#   Control of institution   State  \
# 0                 Public  Kansas
# 1                 Public  Kansas
# 2                 Public  Kansas
# 3                 Public  Kansas
# 4                 Public  Kansas
#
#                                             Variable     SUM     MIN     MAX  \
# 0  Total number of full-time first-time degree/ce...   4,032   4,032   4,032
# 1  Total number of undergraduates - financial aid...  19,245  19,245  19,245
# 2  Grand total - 4-year institutions, Completers ...   2,213   2,213   2,213
# 3  Grand total - Bachelor's or equiv subcohort (4...   2,213   2,213   2,213
# 4  In-district average tuition for full-time unde...   9,579   9,579   9,579
#
#       AVG  25PERCENT  STDEV
# 0   4,032     4032.0    NaN
# 1  19,245    19245.0    NaN
# 2   2,213     2213.0    NaN
# 3   2,213     2213.0    NaN
# 4   9,579     9579.0    NaN

# %%
# Delete extraneous column
del data_source1_df['STDEV']
data_source1_df.head()
# Out:
#   Control of institution   State  \
# 0                 Public  Kansas
# 1                 Public  Kansas
# 2                 Public  Kansas
# 3                 Public  Kansas
# 4                 Public  Kansas
#
#                                             Variable     SUM     MIN     MAX  \
# 0  Total number of full-time first-time degree/ce...   4,032   4,032   4,032
# 1  Total number of undergraduates - financial aid...  19,245  19,245  19,245
# 2  Grand total - 4-year institutions, Completers ...   2,213   2,213   2,213
# 3  Grand total - Bachelor's or equiv subcohort (4...   2,213   2,213   2,213
# 4  In-district average tuition for full-time unde...   9,579   9,579   9,579
#
#       AVG  25PERCENT
# 0   4,032     4032.0
# 1  19,245    19245.0
# 2   2,213     2213.0
# 3   2,213     2213.0
# 4   9,579     9579.0

# %%
# Identify incomplete rows
data_source1_df.count()
# Out:
# Control of institution    84
# State                     84
# Variable                  84
# SUM                       72
# MIN                       72
# MAX                       72
# AVG                       72
# 25PERCENT                 72
# dtype: int64

# %%
# Drop all rows with missing information
data_source1 = data_source1_df.dropna(how='any')

# %%
# Verify dropped rows
data_source1_df.count
# Out:
# <bound method DataFrame.count of    Control of institution     State  \
# 0                  Public    Kansas
# 1                  Public    Kansas
# 2                  Public    Kansas
# 3                  Public    Kansas
# 4                  Public    Kansas
# 5                  Public    Kansas
# 6                  Public    Kansas
# 7                  Public    Kansas
# 8                  Public    Kansas
# 9                  Public    Kansas
# 10                 Public    Kansas
# 11                 Public    Kansas
# 12                 Public    Kansas
# 13                 Public    Kansas
# 14                 Public    Kansas
# 15                 Public    Kansas
# 16                 Public    Kansas
# 17                 Public    Kansas
# 18                 Public    Kansas
# 19                 Public    Kansas
# 20                 Public    Kansas
# 21                 Public    Kansas
# 22                 Public    Kansas
# 23                 Public    Kansas
# ...

# %%
# Delete extraneous column
del data_source1_df['25PERCENT']
data_source1_df.head()
# Out:
#   Control of institution   State  \
# 0                 Public  Kansas
# 1                 Public  Kansas
# 2                 Public  Kansas
# 3                 Public  Kansas
# 4                 Public  Kansas
#
#                                             Variable     SUM     MIN     MAX  \
# 0  Total number of full-time first-time degree/ce...   4,032   4,032   4,032
# 1  Total number of undergraduates - financial aid...  19,245  19,245  19,245
# 2  Grand total - 4-year institutions, Completers ...   2,213   2,213   2,213
# 3  Grand total - Bachelor's or equiv subcohort (4...   2,213   2,213   2,213
# 4  In-district average tuition for full-time unde...   9,579   9,579   9,579
#
#       AVG
# 0   4,032
# 1  19,245
# 2   2,213
# 3   2,213
# 4   9,579

# %%
# Push the remade DataFrame to a new CSV file
data_source1_df.to_csv("Output/data1_clean.csv",
                  encoding="utf-8", index=False, header=True)
